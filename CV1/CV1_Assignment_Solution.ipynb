# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>Cats & Dogs Classification with Pytorch from Scratch</b></p>
#
# ![](https://github.com/TirendazAcademy/End-to-End-Deep-Learning-Projects/blob/main/image_classification_pytorch_comet/Images/images/dog-cat.png?raw=true)
#
#
#
#
# This notebook walks you through how to build a CNN model for image classification and predict data using this model with PyTorch.
#
# ### What is Image Classification?
#
# ![](https://editor.analyticsvidhya.com/uploads/59954intro%20to%20CNN.JPG)
#
# Image classification is the task of assigning a label or class to an input image based on its content. This is typically done using machine learning algorithms that have been trained on a dataset of labeled images. Let's take a look at what we'll learn in this tutorial.
#
# <b>*Table of contents:*</b>
# <ul>
# <li><a href="#Loading">Loading the dataset</a></li>
# <li><a href="#Understanding">Understanding the dataset</a></li>
# <li><a href="#Transforming-data">Transforming data</a></li>
# <li><a href="#Loading-image-data">Loading image data</a></li>
# <li><a href="#Model-building">Model building</a></li>
# <li><a href="#Prediction">Make a prediction</a></li>
# </ul>

# %% [markdown]
# Let's start by looking at the version of the torch.

# %%
import torch
from torch import nn
from torchsummary import summary
# Note: this notebook requires torch >= 1.10.0
torch.__version__
# Out:
# '2.8.0'

# %%
# Setup device-agnostic code --- IGNORE ---
device = "mps" if torch.backends.mps.is_available() else "cpu"
device
# Out:
# 'mps'

# %%
# Setup NVIDIA Cuda device-agnostic code
# device = "cuda" if torch.cuda.is_available() else "cpu"
# device

# %% [markdown]
# <a id="Loading"></a>
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>1. Loading the Dataset</b></p>
#
# The dataset we will use for this tutorial is the cat and dog dataset, which contains images of cats and dogs. Let's take a look at the files in the dataset folder. To do this, let me create a function.

# %%
import os
import gdown
import zipfile
import pandas as pd
import numpy as np

# %%
# The training dataset can be downloaded using the provided code. The data will be extracted into a specified directory.
# dataset_url = "https://drive.google.com/uc?export=download&id=1kTO4N7tD1K-tRX59bqNWSKPdzLaWNgfW"


dataset_path = "./" # the dataset will be downloaded in this folder
zip_file_path =  "training_set-20240919T083719Z-001.zip"
with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
  zip_ref.extractall(dataset_path)

# if not os.path.exists(dataset_path):
#     os.makedirs(dataset_path)
# if not os.path.exists(zip_file_path):
#     gdown.download(dataset_url, zip_file_path, quiet=False)
#     with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
#         zip_ref.extractall(dataset_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[129], line 7
#       5 dataset_path = "./" # the dataset will be downloaded in this folder
#       6 zip_file_path =  "training_set-20240919T083719Z-001.zip"
# ----> 7 with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
#       8   zip_ref.extractall(dataset_path)
#      10 # if not os.path.exists(dataset_path):
#      11 #     os.makedirs(dataset_path)
#      12 # if not os.path.exists(zip_file_path):
#      13 #     gdown.download(dataset_url, zip_file_path, quiet=False)
#      14 #     with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
#      15 #         zip_ref.extractall(dataset_path)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1362, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1360 while True:
#    1361     try:
# -> 1362         self.fp = io.open(file, filemode)
#    1363     except OSError:
#    1364         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'training_set-20240919T083719Z-001.zip'

# %%
# The test dataset can be downloaded using the provided code. The data will be extracted into a specified directory.
# dataset_url = "https://drive.google.com/uc?export=download&id=1vbxkvNT3d9LoSFQO_o-rixo-GXn2QHmu"


dataset_path = "./" # the dataset will be downloaded in this folder
zip_file_path =  "test_set-20240919T083718Z-001.zip"
with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
  zip_ref.extractall(dataset_path)


# if not os.path.exists(dataset_path):
#     os.makedirs(dataset_path)

# if not os.path.exists(zip_file_path):
#     gdown.download(dataset_url, zip_file_path, quiet=False)
#     with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
#         zip_ref.extractall(dataset_path)

# %%
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

image_path = "./"
walk_through_dir(image_path)
# Out:
# There are 5 directories and 6 images in './'.
# There are 1 directories and 1 images in './training_set'.
# There are 2 directories and 0 images in './training_set/training_set'.
# There are 0 directories and 4016 images in './training_set/training_set/dogs'.
# There are 0 directories and 4001 images in './training_set/training_set/cats'.
# There are 0 directories and 1 images in './.ipynb_checkpoints'.
# There are 4 directories and 2 images in './venv'.
# There are 0 directories and 13 images in './venv/bin'.
# There are 1 directories and 0 images in './venv/include'.
# There are 0 directories and 0 images in './venv/include/python3.13'.
# There are 1 directories and 0 images in './venv/lib'.
# There are 1 directories and 0 images in './venv/lib/python3.13'.
# There are 26 directories and 3 images in './venv/lib/python3.13/site-packages'.
# There are 9 directories and 7 images in './venv/lib/python3.13/site-packages/networkx'.
# There are 3 directories and 13 images in './venv/lib/python3.13/site-packages/networkx/readwrite'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/readwrite/json_graph'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/readwrite/json_graph/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/readwrite/json_graph/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/readwrite/json_graph/__pycache__'.
# There are 1 directories and 12 images in './venv/lib/python3.13/site-packages/networkx/readwrite/tests'.
# There are 0 directories and 12 images in './venv/lib/python3.13/site-packages/networkx/readwrite/tests/__pycache__'.
# There are 0 directories and 13 images in './venv/lib/python3.13/site-packages/networkx/readwrite/__pycache__'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/drawing'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/drawing/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/drawing/tests/baseline'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/drawing/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/drawing/__pycache__'.
# There are 2 directories and 8 images in './venv/lib/python3.13/site-packages/networkx/linalg'.
# There are 1 directories and 8 images in './venv/lib/python3.13/site-packages/networkx/linalg/tests'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/networkx/linalg/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/networkx/linalg/__pycache__'.
# There are 2 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/classes'.
# There are 1 directories and 16 images in './venv/lib/python3.13/site-packages/networkx/classes/tests'.
# There are 0 directories and 16 images in './venv/lib/python3.13/site-packages/networkx/classes/tests/__pycache__'.
# There are 0 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/classes/__pycache__'.
# There are 18 directories and 56 images in './venv/lib/python3.13/site-packages/networkx/algorithms'.
# There are 2 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/tree'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/tree/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/tree/tests/__pycache__'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/tree/__pycache__'.
# There are 2 directories and 9 images in './venv/lib/python3.13/site-packages/networkx/algorithms/isomorphism'.
# There are 1 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/isomorphism/tests'.
# There are 0 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/algorithms/isomorphism/tests/__pycache__'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/networkx/algorithms/isomorphism/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/networkx/algorithms/link_analysis'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/networkx/algorithms/link_analysis/tests'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/networkx/algorithms/link_analysis/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/networkx/algorithms/link_analysis/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/algorithms/operators'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/algorithms/operators/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/algorithms/operators/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/networkx/algorithms/operators/__pycache__'.
# There are 2 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/algorithms/connectivity'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/networkx/algorithms/connectivity/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/networkx/algorithms/connectivity/tests/__pycache__'.
# There are 0 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/algorithms/connectivity/__pycache__'.
# There are 2 directories and 15 images in './venv/lib/python3.13/site-packages/networkx/algorithms/approximation'.
# There are 1 directories and 15 images in './venv/lib/python3.13/site-packages/networkx/algorithms/approximation/tests'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/networkx/algorithms/approximation/tests/__pycache__'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/networkx/algorithms/approximation/__pycache__'.
# There are 2 directories and 22 images in './venv/lib/python3.13/site-packages/networkx/algorithms/centrality'.
# There are 1 directories and 21 images in './venv/lib/python3.13/site-packages/networkx/algorithms/centrality/tests'.
# There are 0 directories and 21 images in './venv/lib/python3.13/site-packages/networkx/algorithms/centrality/tests/__pycache__'.
# There are 0 directories and 22 images in './venv/lib/python3.13/site-packages/networkx/algorithms/centrality/__pycache__'.
# There are 1 directories and 57 images in './venv/lib/python3.13/site-packages/networkx/algorithms/tests'.
# There are 0 directories and 57 images in './venv/lib/python3.13/site-packages/networkx/algorithms/tests/__pycache__'.
# There are 0 directories and 56 images in './venv/lib/python3.13/site-packages/networkx/algorithms/__pycache__'.
# There are 2 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/bipartite'.
# There are 1 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/bipartite/tests'.
# There are 0 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/bipartite/tests/__pycache__'.
# There are 0 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/bipartite/__pycache__'.
# There are 2 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/components'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/components/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/components/tests/__pycache__'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/components/__pycache__'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/traversal'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/traversal/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/traversal/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/traversal/__pycache__'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/networkx/algorithms/minors'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/networkx/algorithms/minors/tests'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/networkx/algorithms/minors/tests/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/networkx/algorithms/minors/__pycache__'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/shortest_paths'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/shortest_paths/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/shortest_paths/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/shortest_paths/__pycache__'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/assortativity'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/assortativity/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/algorithms/assortativity/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/assortativity/__pycache__'.
# There are 2 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/community'.
# There are 1 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/community/tests'.
# There are 0 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/community/tests/__pycache__'.
# There are 0 directories and 14 images in './venv/lib/python3.13/site-packages/networkx/algorithms/community/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/networkx/algorithms/coloring'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/networkx/algorithms/coloring/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/networkx/algorithms/coloring/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/networkx/algorithms/coloring/__pycache__'.
# There are 2 directories and 12 images in './venv/lib/python3.13/site-packages/networkx/algorithms/flow'.
# There are 1 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/algorithms/flow/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/networkx/algorithms/flow/tests/__pycache__'.
# There are 0 directories and 12 images in './venv/lib/python3.13/site-packages/networkx/algorithms/flow/__pycache__'.
# There are 1 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/tests'.
# There are 0 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/tests/__pycache__'.
# There are 2 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/utils'.
# There are 1 directories and 11 images in './venv/lib/python3.13/site-packages/networkx/utils/tests'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/networkx/utils/tests/__pycache__'.
# There are 0 directories and 10 images in './venv/lib/python3.13/site-packages/networkx/utils/__pycache__'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/networkx/__pycache__'.
# There are 2 directories and 31 images in './venv/lib/python3.13/site-packages/networkx/generators'.
# There are 1 directories and 29 images in './venv/lib/python3.13/site-packages/networkx/generators/tests'.
# There are 0 directories and 29 images in './venv/lib/python3.13/site-packages/networkx/generators/tests/__pycache__'.
# There are 0 directories and 30 images in './venv/lib/python3.13/site-packages/networkx/generators/__pycache__'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/markupsafe'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/markupsafe/__pycache__'.
# There are 41 directories and 6 images in './venv/lib/python3.13/site-packages/sympy'.
# There are 3 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/series'.
# There are 1 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/series/tests'.
# There are 0 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/series/tests/__pycache__'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/series/__pycache__'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/series/benchmarks'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/series/benchmarks/__pycache__'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/crypto'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/crypto/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/crypto/tests/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/crypto/__pycache__'.
# There are 3 directories and 38 images in './venv/lib/python3.13/site-packages/sympy/core'.
# There are 1 directories and 41 images in './venv/lib/python3.13/site-packages/sympy/core/tests'.
# There are 0 directories and 41 images in './venv/lib/python3.13/site-packages/sympy/core/tests/__pycache__'.
# There are 0 directories and 38 images in './venv/lib/python3.13/site-packages/sympy/core/__pycache__'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/core/benchmarks'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/core/benchmarks/__pycache__'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/unify'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/unify/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/unify/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/unify/__pycache__'.
# There are 7 directories and 43 images in './venv/lib/python3.13/site-packages/sympy/polys'.
# There are 2 directories and 32 images in './venv/lib/python3.13/site-packages/sympy/polys/domains'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/polys/domains/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/polys/domains/tests/__pycache__'.
# There are 0 directories and 32 images in './venv/lib/python3.13/site-packages/sympy/polys/domains/__pycache__'.
# There are 1 directories and 40 images in './venv/lib/python3.13/site-packages/sympy/polys/tests'.
# There are 0 directories and 40 images in './venv/lib/python3.13/site-packages/sympy/polys/tests/__pycache__'.
# There are 0 directories and 43 images in './venv/lib/python3.13/site-packages/sympy/polys/__pycache__'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/polys/benchmarks'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/polys/benchmarks/__pycache__'.
# There are 2 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/polys/numberfields'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/polys/numberfields/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/polys/numberfields/tests/__pycache__'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/polys/numberfields/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/polys/agca'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/polys/agca/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/polys/agca/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/polys/agca/__pycache__'.
# There are 2 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/polys/matrices'.
# There are 1 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/polys/matrices/tests'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/polys/matrices/tests/__pycache__'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/polys/matrices/__pycache__'.
# There are 2 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/concrete'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/concrete/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/concrete/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/concrete/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/holonomic'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/holonomic/tests'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/holonomic/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/holonomic/__pycache__'.
# There are 3 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/strategies'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/strategies/branch'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/strategies/branch/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/strategies/branch/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/strategies/branch/__pycache__'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/strategies/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/strategies/tests/__pycache__'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/strategies/__pycache__'.
# There are 2 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/ntheory'.
# There are 1 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/ntheory/tests'.
# There are 0 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/ntheory/tests/__pycache__'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/ntheory/__pycache__'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/discrete'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/discrete/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/discrete/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/discrete/__pycache__'.
# There are 3 directories and 36 images in './venv/lib/python3.13/site-packages/sympy/printing'.
# There are 1 directories and 36 images in './venv/lib/python3.13/site-packages/sympy/printing/tests'.
# There are 0 directories and 36 images in './venv/lib/python3.13/site-packages/sympy/printing/tests/__pycache__'.
# There are 0 directories and 36 images in './venv/lib/python3.13/site-packages/sympy/printing/__pycache__'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/printing/pretty'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/printing/pretty/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/printing/pretty/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/printing/pretty/__pycache__'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/algebras'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/algebras/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/algebras/tests/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/algebras/__pycache__'.
# There are 4 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/logic'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/logic/algorithms'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/logic/algorithms/__pycache__'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/logic/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/logic/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/logic/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/logic/utilities'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/logic/utilities/__pycache__'.
# There are 5 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/solvers'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/solvers/diophantine'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/solvers/diophantine/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/solvers/diophantine/tests/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/solvers/diophantine/__pycache__'.
# There are 1 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/solvers/tests'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/solvers/tests/__pycache__'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/solvers/__pycache__'.
# There are 2 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/solvers/ode'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/solvers/ode/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/solvers/ode/tests/__pycache__'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/solvers/ode/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/solvers/benchmarks'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/solvers/benchmarks/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/__pycache__'.
# There are 2 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/codegen'.
# There are 1 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/codegen/tests'.
# There are 0 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/codegen/tests/__pycache__'.
# There are 0 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/codegen/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/multipledispatch'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/multipledispatch/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/multipledispatch/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/multipledispatch/__pycache__'.
# There are 2 directories and 13 images in './venv/lib/python3.13/site-packages/sympy/liealgebras'.
# There are 1 directories and 13 images in './venv/lib/python3.13/site-packages/sympy/liealgebras/tests'.
# There are 0 directories and 13 images in './venv/lib/python3.13/site-packages/sympy/liealgebras/tests/__pycache__'.
# There are 0 directories and 13 images in './venv/lib/python3.13/site-packages/sympy/liealgebras/__pycache__'.
# There are 4 directories and 19 images in './venv/lib/python3.13/site-packages/sympy/utilities'.
# There are 2 directories and 1 images in './venv/lib/python3.13/site-packages/sympy/utilities/mathml'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/sympy/utilities/mathml/__pycache__'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/utilities/mathml/data'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/sympy/utilities/mathml/data/__pycache__'.
# There are 1 directories and 20 images in './venv/lib/python3.13/site-packages/sympy/utilities/tests'.
# There are 0 directories and 20 images in './venv/lib/python3.13/site-packages/sympy/utilities/tests/__pycache__'.
# There are 0 directories and 19 images in './venv/lib/python3.13/site-packages/sympy/utilities/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/utilities/_compilation'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/utilities/_compilation/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/utilities/_compilation/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/utilities/_compilation/__pycache__'.
# There are 2 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/testing'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/testing/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/testing/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/testing/__pycache__'.
# There are 3 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/integrals'.
# There are 1 directories and 18 images in './venv/lib/python3.13/site-packages/sympy/integrals/tests'.
# There are 0 directories and 18 images in './venv/lib/python3.13/site-packages/sympy/integrals/tests/__pycache__'.
# There are 0 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/integrals/__pycache__'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/integrals/benchmarks'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/integrals/benchmarks/__pycache__'.
# There are 5 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/assumptions'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/assumptions/predicates'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/assumptions/predicates/__pycache__'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/assumptions/relation'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/assumptions/relation/__pycache__'.
# There are 1 directories and 10 images in './venv/lib/python3.13/site-packages/sympy/assumptions/tests'.
# There are 0 directories and 10 images in './venv/lib/python3.13/site-packages/sympy/assumptions/tests/__pycache__'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/assumptions/__pycache__'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/assumptions/handlers'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/assumptions/handlers/__pycache__'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/sandbox'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/sandbox/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/sandbox/tests/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/sandbox/__pycache__'.
# There are 5 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/plotting'.
# There are 2 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/plotting/pygletplot'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/pygletplot/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/pygletplot/tests/__pycache__'.
# There are 0 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/plotting/pygletplot/__pycache__'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/plotting/intervalmath'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/plotting/intervalmath/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/plotting/intervalmath/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/plotting/intervalmath/__pycache__'.
# There are 3 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/backends'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/backends/matplotlibbackend'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/backends/matplotlibbackend/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/backends/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/backends/textbackend'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/plotting/backends/textbackend/__pycache__'.
# There are 1 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/plotting/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/plotting/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/plotting/__pycache__'.
# There are 3 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/sets'.
# There are 1 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/sets/tests'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/sets/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/sets/__pycache__'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/sets/handlers'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/sets/handlers/__pycache__'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/benchmarks'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/benchmarks/__pycache__'.
# There are 2 directories and 24 images in './venv/lib/python3.13/site-packages/sympy/combinatorics'.
# There are 1 directories and 23 images in './venv/lib/python3.13/site-packages/sympy/combinatorics/tests'.
# There are 0 directories and 23 images in './venv/lib/python3.13/site-packages/sympy/combinatorics/tests/__pycache__'.
# There are 0 directories and 24 images in './venv/lib/python3.13/site-packages/sympy/combinatorics/__pycache__'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/interactive'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/interactive/tests'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/interactive/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/interactive/__pycache__'.
# There are 4 directories and 1 images in './venv/lib/python3.13/site-packages/sympy/functions'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/sympy/functions/__pycache__'.
# There are 3 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/functions/special'.
# There are 1 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/functions/special/tests'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/functions/special/tests/__pycache__'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/functions/special/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/functions/special/benchmarks'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/functions/special/benchmarks/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/functions/combinatorial'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/functions/combinatorial/tests'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/functions/combinatorial/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/functions/combinatorial/__pycache__'.
# There are 3 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/functions/elementary'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/functions/elementary/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/functions/elementary/tests/__pycache__'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/functions/elementary/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/functions/elementary/benchmarks'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/functions/elementary/benchmarks/__pycache__'.
# There are 3 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/tensor'.
# There are 3 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/tensor/array'.
# There are 1 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/tests'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/__pycache__'.
# There are 2 directories and 12 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/expressions'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/expressions/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/expressions/tests/__pycache__'.
# There are 0 directories and 12 images in './venv/lib/python3.13/site-packages/sympy/tensor/array/expressions/__pycache__'.
# There are 1 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/tensor/tests'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/tensor/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/tensor/__pycache__'.
# There are 2 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/geometry'.
# There are 1 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/geometry/tests'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/geometry/tests/__pycache__'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/geometry/__pycache__'.
# There are 11 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/physics'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/physics/hep'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/physics/hep/tests'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/physics/hep/tests/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/physics/hep/__pycache__'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/physics/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/physics/tests/__pycache__'.
# There are 2 directories and 19 images in './venv/lib/python3.13/site-packages/sympy/physics/mechanics'.
# There are 1 directories and 25 images in './venv/lib/python3.13/site-packages/sympy/physics/mechanics/tests'.
# There are 0 directories and 25 images in './venv/lib/python3.13/site-packages/sympy/physics/mechanics/tests/__pycache__'.
# There are 0 directories and 19 images in './venv/lib/python3.13/site-packages/sympy/physics/mechanics/__pycache__'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/physics/__pycache__'.
# There are 4 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/physics/units'.
# There are 1 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/physics/units/tests'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/physics/units/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/physics/units/__pycache__'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/physics/units/systems'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/sympy/physics/units/systems/__pycache__'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/physics/units/definitions'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/physics/units/definitions/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/biomechanics'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/biomechanics/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/biomechanics/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/biomechanics/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/continuum_mechanics'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/continuum_mechanics/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/continuum_mechanics/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/physics/continuum_mechanics/__pycache__'.
# There are 2 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/physics/vector'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/physics/vector/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/physics/vector/tests/__pycache__'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/physics/vector/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/physics/control'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/physics/control/tests'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/physics/control/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/physics/control/__pycache__'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/physics/optics'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/physics/optics/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/physics/optics/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/physics/optics/__pycache__'.
# There are 2 directories and 38 images in './venv/lib/python3.13/site-packages/sympy/physics/quantum'.
# There are 1 directories and 38 images in './venv/lib/python3.13/site-packages/sympy/physics/quantum/tests'.
# There are 0 directories and 38 images in './venv/lib/python3.13/site-packages/sympy/physics/quantum/tests/__pycache__'.
# There are 0 directories and 38 images in './venv/lib/python3.13/site-packages/sympy/physics/quantum/__pycache__'.
# There are 2 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/external'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/external/tests'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/sympy/external/tests/__pycache__'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/external/__pycache__'.
# There are 6 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/parsing'.
# There are 3 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex/_antlr'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex/_antlr/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex/lark'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex/lark/grammar'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex/lark/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/parsing/latex/__pycache__'.
# There are 1 directories and 14 images in './venv/lib/python3.13/site-packages/sympy/parsing/tests'.
# There are 0 directories and 14 images in './venv/lib/python3.13/site-packages/sympy/parsing/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/parsing/__pycache__'.
# There are 3 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/_antlr'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/_antlr/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/__pycache__'.
# There are 2 directories and 25 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/test-examples'.
# There are 0 directories and 12 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/test-examples/__pycache__'.
# There are 1 directories and 8 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/test-examples/pydy-example-repo'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/parsing/autolev/test-examples/pydy-example-repo/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/parsing/fortran'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/parsing/fortran/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/parsing/c'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/parsing/c/__pycache__'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/calculus'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/calculus/tests'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/calculus/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/sympy/calculus/__pycache__'.
# There are 2 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/simplify'.
# There are 1 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/simplify/tests'.
# There are 0 directories and 16 images in './venv/lib/python3.13/site-packages/sympy/simplify/tests/__pycache__'.
# There are 0 directories and 17 images in './venv/lib/python3.13/site-packages/sympy/simplify/__pycache__'.
# There are 2 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/vector'.
# There are 1 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/vector/tests'.
# There are 0 directories and 11 images in './venv/lib/python3.13/site-packages/sympy/vector/tests/__pycache__'.
# There are 0 directories and 15 images in './venv/lib/python3.13/site-packages/sympy/vector/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/categories'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/categories/tests'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/categories/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/categories/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/diffgeom'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/diffgeom/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/sympy/diffgeom/tests/__pycache__'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/sympy/diffgeom/__pycache__'.
# There are 3 directories and 20 images in './venv/lib/python3.13/site-packages/sympy/stats'.
# There are 1 directories and 14 images in './venv/lib/python3.13/site-packages/sympy/stats/tests'.
# There are 0 directories and 14 images in './venv/lib/python3.13/site-packages/sympy/stats/tests/__pycache__'.
# There are 2 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/stats/sampling'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/stats/sampling/tests'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/stats/sampling/tests/__pycache__'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/sympy/stats/sampling/__pycache__'.
# There are 0 directories and 20 images in './venv/lib/python3.13/site-packages/sympy/stats/__pycache__'.
# There are 4 directories and 21 images in './venv/lib/python3.13/site-packages/sympy/matrices'.
# There are 1 directories and 18 images in './venv/lib/python3.13/site-packages/sympy/matrices/tests'.
# There are 0 directories and 18 images in './venv/lib/python3.13/site-packages/sympy/matrices/tests/__pycache__'.
# There are 0 directories and 21 images in './venv/lib/python3.13/site-packages/sympy/matrices/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/matrices/benchmarks'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/sympy/matrices/benchmarks/__pycache__'.
# There are 2 directories and 25 images in './venv/lib/python3.13/site-packages/sympy/matrices/expressions'.
# There are 1 directories and 26 images in './venv/lib/python3.13/site-packages/sympy/matrices/expressions/tests'.
# There are 0 directories and 26 images in './venv/lib/python3.13/site-packages/sympy/matrices/expressions/tests/__pycache__'.
# There are 0 directories and 25 images in './venv/lib/python3.13/site-packages/sympy/matrices/expressions/__pycache__'.
# There are 6 directories and 12 images in './venv/lib/python3.13/site-packages/mpmath'.
# ...
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/jaraco/collections/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/jaraco.functools-4.0.1.dist-info'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/jaraco.context-5.3.0.dist-info'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/inflect-7.3.1.dist-info'.
# There are 2 directories and 10 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/importlib_metadata'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/importlib_metadata/compat'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/importlib_metadata/compat/__pycache__'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/importlib_metadata/__pycache__'.
# There are 3 directories and 9 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/__pycache__'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/cli'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/cli/__pycache__'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/vendored'.
# There are 1 directories and 16 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/vendored/packaging'.
# There are 0 directories and 13 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/vendored/packaging/__pycache__'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel/vendored/__pycache__'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/zipp'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/zipp/compat'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/zipp/compat/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/zipp/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/autocommand-2.2.2.dist-info'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/__pycache__'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/more_itertools'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/more_itertools/__pycache__'.
# There are 2 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports'.
# There are 2 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports/tarfile'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports/tarfile/compat'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports/tarfile/compat/__pycache__'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports/tarfile/__pycache__'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports/__pycache__'.
# There are 1 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/autocommand'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/autocommand/__pycache__'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/tomli'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/tomli/__pycache__'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/backports.tarfile-1.2.0.dist-info'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/typeguard-4.3.0.dist-info'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/packaging-24.2.dist-info'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/wheel-0.45.1.dist-info'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/zipp-3.19.2.dist-info'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/tomli-2.0.1.dist-info'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/typing_extensions-4.12.2.dist-info'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/more_itertools-10.3.0.dist-info'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/platformdirs-4.2.2.dist-info'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/platformdirs-4.2.2.dist-info/licenses'.
# There are 1 directories and 14 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/typeguard'.
# There are 0 directories and 13 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/typeguard/__pycache__'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/platformdirs'.
# There are 0 directories and 8 images in './venv/lib/python3.13/site-packages/setuptools/_vendor/platformdirs/__pycache__'.
# There are 2 directories and 8 images in './venv/lib/python3.13/site-packages/setuptools/config'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/config/__pycache__'.
# There are 1 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/config/_validate_pyproject'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/config/_validate_pyproject/__pycache__'.
# There are 5 directories and 45 images in './venv/lib/python3.13/site-packages/setuptools/tests'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/tests/compat'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/tests/compat/__pycache__'.
# There are 2 directories and 7 images in './venv/lib/python3.13/site-packages/setuptools/tests/config'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/tests/config/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/tests/config/downloads'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/tests/config/downloads/__pycache__'.
# There are 1 directories and 4 images in './venv/lib/python3.13/site-packages/setuptools/tests/integration'.
# There are 0 directories and 4 images in './venv/lib/python3.13/site-packages/setuptools/tests/integration/__pycache__'.
# There are 0 directories and 45 images in './venv/lib/python3.13/site-packages/setuptools/tests/__pycache__'.
# There are 1 directories and 0 images in './venv/lib/python3.13/site-packages/setuptools/tests/indexes'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/tests/indexes/test_links_priority'.
# There are 1 directories and 0 images in './venv/lib/python3.13/site-packages/setuptools/tests/indexes/test_links_priority/simple'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/setuptools/tests/indexes/test_links_priority/simple/foobar'.
# There are 0 directories and 33 images in './venv/lib/python3.13/site-packages/setuptools/__pycache__'.
# There are 1 directories and 25 images in './venv/lib/python3.13/site-packages/setuptools/command'.
# There are 0 directories and 24 images in './venv/lib/python3.13/site-packages/setuptools/command/__pycache__'.
# There are 5 directories and 28 images in './venv/lib/python3.13/site-packages/setuptools/_distutils'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compat'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compat/__pycache__'.
# There are 2 directories and 36 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/tests'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/tests/compat'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/tests/compat/__pycache__'.
# There are 0 directories and 36 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/tests/__pycache__'.
# There are 0 directories and 28 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/__pycache__'.
# There are 1 directories and 20 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/command'.
# There are 0 directories and 20 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/command/__pycache__'.
# There are 1 directories and 0 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compilers'.
# There are 2 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compilers/C'.
# There are 1 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compilers/C/tests'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compilers/C/tests/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/setuptools/_distutils/compilers/C/__pycache__'.
# There are 2 directories and 3 images in './venv/lib/python3.13/site-packages/pkg_resources'.
# There are 2 directories and 7 images in './venv/lib/python3.13/site-packages/pkg_resources/tests'.
# There are 0 directories and 7 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/__pycache__'.
# There are 4 directories and 0 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package-zip'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package_zipped-egg'.
# There are 1 directories and 0 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package_unpacked-egg'.
# There are 1 directories and 0 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package_unpacked-egg/my_test_package-1.0-py3.7.egg'.
# There are 0 directories and 5 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package_unpacked-egg/my_test_package-1.0-py3.7.egg/EGG-INFO'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package-source'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/pkg_resources/tests/data/my-test-package-source/__pycache__'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/pkg_resources/__pycache__'.
# There are 1 directories and 2 images in './venv/lib/python3.13/site-packages/_distutils_hack'.
# There are 0 directories and 2 images in './venv/lib/python3.13/site-packages/_distutils_hack/__pycache__'.
# There are 6 directories and 2 images in './venv/lib/python3.13/site-packages/functorch'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/functorch/experimental'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/functorch/experimental/__pycache__'.
# There are 5 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/make_functional'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/make_functional/__pycache__'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/__pycache__'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/eager_transforms'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/eager_transforms/__pycache__'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/aot_autograd'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/aot_autograd/__pycache__'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/vmap'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/_src/vmap/__pycache__'.
# There are 1 directories and 9 images in './venv/lib/python3.13/site-packages/functorch/dim'.
# There are 0 directories and 9 images in './venv/lib/python3.13/site-packages/functorch/dim/__pycache__'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/__pycache__'.
# There are 1 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/compile'.
# There are 0 directories and 1 images in './venv/lib/python3.13/site-packages/functorch/compile/__pycache__'.
# There are 1 directories and 3 images in './venv/lib/python3.13/site-packages/functorch/einops'.
# There are 0 directories and 3 images in './venv/lib/python3.13/site-packages/functorch/einops/__pycache__'.
# There are 0 directories and 6 images in './venv/lib/python3.13/site-packages/MarkupSafe-3.0.2.dist-info'.
# There are 1 directories and 0 images in './venv/share'.
# There are 1 directories and 0 images in './venv/share/man'.
# There are 0 directories and 1 images in './venv/share/man/man1'.
# There are 5 directories and 8 images in './.git'.
# There are 13 directories and 0 images in './.git/objects'.
# There are 0 directories and 1 images in './.git/objects/0d'.
# There are 0 directories and 1 images in './.git/objects/92'.
# There are 0 directories and 1 images in './.git/objects/9d'.
# There are 0 directories and 2 images in './.git/objects/e2'.
# There are 0 directories and 2 images in './.git/objects/pack'.
# There are 0 directories and 1 images in './.git/objects/86'.
# There are 0 directories and 1 images in './.git/objects/36'.
# There are 0 directories and 0 images in './.git/objects/info'.
# There are 0 directories and 2 images in './.git/objects/65'.
# There are 0 directories and 1 images in './.git/objects/62'.
# There are 0 directories and 1 images in './.git/objects/37'.
# There are 0 directories and 1 images in './.git/objects/79'.
# There are 0 directories and 1 images in './.git/objects/22'.
# There are 0 directories and 1 images in './.git/info'.
# There are 1 directories and 1 images in './.git/logs'.
# There are 2 directories and 0 images in './.git/logs/refs'.
# There are 0 directories and 1 images in './.git/logs/refs/heads'.
# There are 1 directories and 0 images in './.git/logs/refs/remotes'.
# There are 0 directories and 2 images in './.git/logs/refs/remotes/origin'.
# There are 0 directories and 13 images in './.git/hooks'.
# There are 3 directories and 0 images in './.git/refs'.
# There are 0 directories and 1 images in './.git/refs/heads'.
# There are 0 directories and 0 images in './.git/refs/tags'.
# There are 1 directories and 0 images in './.git/refs/remotes'.
# There are 0 directories and 2 images in './.git/refs/remotes/origin'.
# There are 1 directories and 0 images in './test_set'.
# There are 2 directories and 0 images in './test_set/test_set'.
# There are 0 directories and 1013 images in './test_set/test_set/dogs'.
# There are 0 directories and 1012 images in './test_set/test_set/cats'.

# %% [markdown]
# Nice! We saw the files in the dataset folder. Now let's create train and testing paths:

# %%
train_dir = "./training_set/training_set"
test_dir = "./test_set/test_set"
train_dir, test_dir
# Out:
# ('./training_set/training_set', './test_set/test_set')

# %% [markdown]
# <a id="Understanding"></a>
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>2. Understanding the Dataset</b></p>
#
# It is important to understand the dataset for deep learning analysis because the dataset is the foundation of any machine learning or deep learning model. A deep learning model can only be as good as the data it is trained on, and a poor understanding of the dataset can lead to poor model performance or even bias. Now let's take a look at an image in the dataset.

# %%
import random
from PIL import Image
import glob
from pathlib import Path

# %%
# Set seed
#random.seed(42)

# 1. Get all image paths (* means "any combination")
image_path_list= glob.glob(f"{image_path}/*/*/*/*.jpg")

# 2. Get random image path
random_image_path = random.choice(image_path_list)

# 3. Get image class from path name (the image class is the name of the directory where the image is stored)
image_class = Path(random_image_path).parent.stem

# 4. Open image
img = Image.open(random_image_path)

# 5. Print metadata
print(f"Random image path: {random_image_path}")
print(f"Image class: {image_class}")
print(f"Image height: {img.height}")
print(f"Image width: {img.width}")
img
# Out:
# Random image path: ./training_set/training_set/cats/cat.638.jpg
# Image class: cats
# Image height: 375
# Image width: 499
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x375>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Turn the image into an array
img_as_array = np.asarray(img)

# Plot the image with matplotlib
plt.figure(figsize=(8, 6))
plt.imshow(img_as_array)
plt.title(f"Image class: {image_class} | Image shape: {img_as_array.shape} -> [height, width, color_channels]")
plt.axis(False);

# %% [markdown]
# <a id="Transforming-data"></a>
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>3. Transforming Data</b></p>
#
# Transforming data, also known as preprocessing, is an important step in deep learning analysis because it can help to improve the performance of the model and reduce the risk of bias. Let's play with the images a bit with the `transform` method.

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)

# Write transform for image
data_transform = transforms.Compose([
    # Resize the images to IMAGE_SIZE xIMAGE_SIZE
    transforms.Resize(size=IMAGE_SIZE),
    # Flip the images randomly on the horizontal
    transforms.RandomHorizontalFlip(p=0.5), # p = probability of flip, 0.5 = 50% chance
    # Turn the image into a torch.Tensor
    transforms.ToTensor() # this also converts all pixel values from 0 to 255 to be between 0.0 and 1.0
])

# %% [markdown]
# To understand how to transform the images, let's use data visualization. To do this, I'm going to craete a function named plot_transformed_images.

# %%
def plot_transformed_images(image_paths, transform, n=3, seed=42):
    random.seed(seed)
    random_image_paths = random.sample(image_paths, k=n)
    for image_path in random_image_paths:
        with Image.open(image_path) as f:
            fig, ax = plt.subplots(1, 2)
            ax[0].imshow(f)
            ax[0].set_title(f"Original \nSize: {f.size}")
            ax[0].axis("off")

            # Transform and plot image
            # Note: permute() will change shape of image to suit matplotlib
            # (PyTorch default is [C, H, W] but Matplotlib is [H, W, C])
            transformed_image = transform(f).permute(1, 2, 0)
            ax[1].imshow(transformed_image)
            ax[1].set_title(f"Transformed \nSize: {transformed_image.shape}")
            ax[1].axis("off")
            fig.suptitle(f"Class: {Path(random_image_path).parent.stem}", fontsize=16)

plot_transformed_images(image_path_list, transform=data_transform, n=5)

# %% [markdown]
# Nice! we saw how to transform images. Let's go ahead and load our dataset.

# %% [markdown]
# <a id="Loading-image-data"></a>
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>4. Loading Image Data</b></p>
# So far, we created a data transformation function. We are ready to load our dataset using this function. The easiest way to load data is to use the `ImageFolder` function in PyTorch. Let's load the dataset with this function.

# %%
from torchvision import datasets

# Creating training set
train_data = datasets.ImageFolder(root=train_dir, # target folder of images
                                  transform=data_transform, # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)
#Creating test set
test_data = datasets.ImageFolder(root=test_dir, transform=data_transform)

print(f"Train data:\n{train_data}\nTest data:\n{test_data}")
# Out:
# Train data:
# Dataset ImageFolder
#     Number of datapoints: 8015
#     Root location: ./training_set/training_set
#     StandardTransform
# Transform: Compose(
#                Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )
# Test data:
# Dataset ImageFolder
#     Number of datapoints: 2023
#     Root location: ./test_set/test_set
#     StandardTransform
# Transform: Compose(
#                Resize(size=(128, 128), interpolation=bilinear, max_size=None, antialias=True)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#            )

# %% [markdown]
# Now let's discover the dataset using the attributes as shown below.

# %%
# Get class names as a list
class_names = train_data.classes
print("Class names: ",class_names)

# Can also get class names as a dict
class_dict = train_data.class_to_idx
print("Class names as a dict: ",class_dict)

# Check the lengths
print("The lengths of the training and test sets: ", len(train_data), len(test_data))
# Out:
# Class names:  ['cats', 'dogs']
# Class names as a dict:  {'cats': 0, 'dogs': 1}
# The lengths of the training and test sets:  8015 2023

# %% [markdown]
# Awesome. We learned some information about the datasets. Let's get an image and have a look at its features.

# %%
img, label = train_data[0][0], train_data[0][1]
print(f"Image tensor:\n{img}")
print(f"Image shape: {img.shape}")
print(f"Image datatype: {img.dtype}")
print(f"Image label: {label}")
print(f"Label datatype: {type(label)}")
# Out:
# Image tensor:
# tensor([[[0.1569, 0.1608, 0.1608,  ..., 0.6196, 0.7765, 0.7882],
#          [0.1529, 0.1490, 0.1490,  ..., 0.6118, 0.7529, 0.7882],
#          [0.1490, 0.1333, 0.1333,  ..., 0.6118, 0.7373, 0.7882],
#          ...,
#          [0.0863, 0.0784, 0.0784,  ..., 0.2392, 0.2627, 0.1725],
#          [0.1098, 0.0902, 0.0863,  ..., 0.2196, 0.1804, 0.1725],
#          [0.1176, 0.0902, 0.0863,  ..., 0.2431, 0.1804, 0.1765]],
#
#         [[0.1765, 0.1765, 0.1725,  ..., 0.6235, 0.7686, 0.7725],
#          [0.1725, 0.1647, 0.1608,  ..., 0.6118, 0.7373, 0.7686],
#          [0.1686, 0.1490, 0.1451,  ..., 0.6039, 0.7137, 0.7608],
#          ...,
#          [0.0784, 0.0706, 0.0706,  ..., 0.1725, 0.2078, 0.1255],
#          [0.1020, 0.0824, 0.0784,  ..., 0.1569, 0.1255, 0.1255],
#          [0.1098, 0.0824, 0.0784,  ..., 0.1804, 0.1255, 0.1373]],
#
#         [[0.1608, 0.1765, 0.1922,  ..., 0.5843, 0.6706, 0.6431],
#          [0.1569, 0.1647, 0.1804,  ..., 0.5804, 0.6471, 0.6510],
#          [0.1529, 0.1490, 0.1647,  ..., 0.5843, 0.6392, 0.6510],
#          ...,
#          [0.0824, 0.0745, 0.0745,  ..., 0.1608, 0.1882, 0.1020],
#          [0.1059, 0.0863, 0.0824,  ..., 0.1373, 0.1020, 0.1020],
#          [0.1137, 0.0863, 0.0824,  ..., 0.1569, 0.0941, 0.1020]]])
# Image shape: torch.Size([3, 128, 128])
# Image datatype: torch.float32
# Image label: 0
# Label datatype: <class 'int'>

# %% [markdown]
# Let's visualize this image with matplotlib.

# %%
# Rearrange the order of dimensions
img_permute = img.permute(1, 2, 0)

# Print out different shapes (before and after permute)
print(f"Original shape: {img.shape} -> [color_channels, height, width]")
print(f"Image permute shape: {img_permute.shape} -> [height, width, color_channels]")

# Plot the image
plt.figure(figsize=(10, 7))
plt.imshow(img.permute(1, 2, 0))
plt.axis("off")
plt.title(class_names[label], fontsize=14);
# Out:
# Original shape: torch.Size([3, 128, 128]) -> [color_channels, height, width]
# Image permute shape: torch.Size([128, 128, 3]) -> [height, width, color_channels]

# %% [markdown]
# ## Turn loaded images into DataLoader's
#
# So far, we loaded images. Note that a `DataLoader` in PyTorch is a utility used to load data from a dataset object in parallel. It allows the user to load data in batches, which can be useful for training deep learning models, as it enables the model to process multiple samples at once, which can speed up the training process. Additionally, it also allows the user to shuffle the data, which can help to prevent overfitting.
#
# The DataLoader takes a dataset object and several other optional parameters, such as the batch size, the number of worker threads to use for loading the data, and a boolean flag for whether or not to shuffle the data. The DataLoader will then return an iterator that can be used to iterate over the data in batches.

# %%
from torch.utils.data import DataLoader

# How many subprocesses will be used for data loading (higher = more)
NUM_WORKERS = os.cpu_count()
print(f"Number of workers in DataLoader: {NUM_WORKERS}")

# Turn train and test Datasets into DataLoaders
train_dataloader = DataLoader(dataset=train_data,
                              batch_size=2, # how many samples per batch?
                              num_workers=NUM_WORKERS,
                              shuffle=True) # shuffle the data?

test_dataloader = DataLoader(dataset=test_data,
                             batch_size=1,
                             num_workers=NUM_WORKERS,
                             shuffle=False) # don't usually need to shuffle testing data

train_dataloader, test_dataloader
# Out:
# Number of workers in DataLoader: 14
# (<torch.utils.data.dataloader.DataLoader at 0x16c0616d0>,
#  <torch.utils.data.dataloader.DataLoader at 0x16ba33820>)

# %% [markdown]
# Nice. We turn our dataset into a `DataLoader` object. Now let's get a batch image and check the shape of this batch.

# %%
img, label = next(iter(train_dataloader))

# Note that batch size will now be 1.
print(f"Image shape: {img.shape} -> [batch_size, color_channels, height, width]")
print(f"Label shape: {label.shape}")
# Out:
# Image shape: torch.Size([2, 3, 128, 128]) -> [batch_size, color_channels, height, width]
# Label shape: torch.Size([2])

# %% [markdown]
# <a id="Model-building"></a>
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>5. Model Building with Data Augmentation</b></p>
#
# Have you heard of what data augmentation is? Data augmentation is a technique used to artificially increase the size of a dataset by applying random modifications to the existing data. This can help to improve the performance of deep learning models by providing the model with more diverse training examples. Data augmentation can be useful when the available dataset is small or when the model is prone to overfitting.
#
# Some common data augmentation techniques include:
#
# - Random flipping or rotation of images
# - Random cropping of images
# - Random changes to brightness, contrast or color
# - Adding noise to images
# - Scaling or translation of images
#
# By using data augmentation techniques, the model can learn to generalize better and become more robust to small variations in the data. This can help to prevent overfitting and improve the model's performance on unseen data. It is important to note that data augmentation should be performed before data preprocessing. Keep in mind data augmentation should be applied only to the training set, not the validation or test set.

# %% [markdown]
# ## 5.1 Creating transforms and loading data
#
# TrivialAugmentWide is a data augmentation technique in PyTorch that applies random resizing and cropping to an image. The technique is intended to be used as a "wide" data augmentation technique, meaning that it makes a large number of random transformations to the image in order to increase the diversity of the training data. This can help to improve the robustness and generalization of a machine learning model. [This example](https://pytorch.org/vision/stable/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py) illustrates the various transforms available in the torchvision.transforms module.

# %%
# Set image size.
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)

# Create training transform with TrivialAugment
train_transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.TrivialAugmentWide(),
    transforms.ToTensor()])

# Create testing transform (no data augmentation)
test_transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor()])

# %% [markdown]
# Now let's load our dataset with data augmentation again.

# %%
# Turn image folders into Datasets
train_data_augmented = datasets.ImageFolder(train_dir, transform=train_transform)
test_data_augmented = datasets.ImageFolder(test_dir, transform=test_transform)

train_data_augmented, test_data_augmented
# Out:
# (Dataset ImageFolder
#      Number of datapoints: 8015
#      Root location: ./training_set/training_set
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                 TrivialAugmentWide(num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#                 ToTensor()
#             ),
#  Dataset ImageFolder
#      Number of datapoints: 2023
#      Root location: ./test_set/test_set
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#                 ToTensor()
#             ))

# %% [markdown]
# Now let's turn Datasets into DataLoader's.

# %%
# Set some parameters.
BATCH_SIZE = 32
torch.manual_seed(42)

train_dataloader_augmented = DataLoader(train_data_augmented,
                                        batch_size=BATCH_SIZE,
                                        shuffle=True,
                                        num_workers=NUM_WORKERS)

test_dataloader_augmented = DataLoader(test_data_augmented,
                                       batch_size=BATCH_SIZE,
                                       shuffle=False,
                                       num_workers=NUM_WORKERS)

train_dataloader_augmented, test_dataloader_augmented
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x147804f30>,
#  <torch.utils.data.dataloader.DataLoader at 0x16ba57020>)

# %% [markdown]
# Nice! We created the `DataLoader` objects. Let's go ahead and build an image classification architecture.

# %% [markdown]
# ## 5.2 Creating CNN Image Classifier

# %% [markdown]
# A convolutional neural network (CNN) is a type of deep learning neural network that is primarily used for image and video recognition tasks. CNNs are designed to process data that has a grid-like topology, such as an image, which is composed of pixels arranged in a 2D grid. The architecture of a CNN consists of several layers, including convolutional layers, pooling layers, and fully connected layers.
#
# The convolutional layers are responsible for detecting features in the input image by applying a set of learnable filters to the image. These filters are convolved with the input image to produce a set of feature maps, which are then passed through pooling layers to reduce the spatial dimensions of the feature maps and retain only the most salient features. The fully connected layers then process the pooled feature maps to produce the final output, such as a classification label.
#
# CNNs have been used to achieve state-of-the-art results on a wide range of computer vision tasks such as image classification, object detection, and semantic segmentation. Now let's go ahead and build a CNN model with nn.Module in Pytorch.

# %%
# # Creating a CNN-based image classifier.
class ImageClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv_layer_1 = nn.Sequential(
          nn.Conv2d(3, 64, 3, padding=1),
          nn.ReLU(),
          nn.BatchNorm2d(64),
          nn.MaxPool2d(2))
        self.conv_layer_2 = nn.Sequential(
          nn.Conv2d(64, 512, 3, padding=1),
          nn.ReLU(),
          nn.BatchNorm2d(512),
          nn.MaxPool2d(2))
        self.conv_layer_3 = nn.Sequential(
          nn.Conv2d(512, 512, kernel_size=3, padding=1),
          nn.ReLU(),
          nn.BatchNorm2d(512),
          nn.MaxPool2d(2))
        self.classifier = nn.Sequential(
          nn.Flatten(),
          nn.Linear(in_features=512*3*3, out_features=2))
    def forward(self, x: torch.Tensor):
        x = self.conv_layer_1(x)
        x = self.conv_layer_2(x)
        x = self.conv_layer_3(x)
        x = self.conv_layer_3(x)
        x = self.conv_layer_3(x)
        x = self.conv_layer_3(x)
        x = self.classifier(x)
        return x
#model = ImageClassifier().to(device)
model = ImageClassifier()

# %%
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#        BatchNorm2d-3         [-1, 64, 224, 224]             128
#          MaxPool2d-4         [-1, 64, 112, 112]               0
#             Conv2d-5        [-1, 512, 112, 112]         295,424
#               ReLU-6        [-1, 512, 112, 112]               0
#        BatchNorm2d-7        [-1, 512, 112, 112]           1,024
#          MaxPool2d-8          [-1, 512, 56, 56]               0
#             Conv2d-9          [-1, 512, 56, 56]       2,359,808
#              ReLU-10          [-1, 512, 56, 56]               0
#       BatchNorm2d-11          [-1, 512, 56, 56]           1,024
#         MaxPool2d-12          [-1, 512, 28, 28]               0
#            Conv2d-13          [-1, 512, 28, 28]       2,359,808
#              ReLU-14          [-1, 512, 28, 28]               0
#       BatchNorm2d-15          [-1, 512, 28, 28]           1,024
#         MaxPool2d-16          [-1, 512, 14, 14]               0
#            Conv2d-17          [-1, 512, 14, 14]       2,359,808
#              ReLU-18          [-1, 512, 14, 14]               0
#       BatchNorm2d-19          [-1, 512, 14, 14]           1,024
#         MaxPool2d-20            [-1, 512, 7, 7]               0
#            Conv2d-21            [-1, 512, 7, 7]       2,359,808
#              ReLU-22            [-1, 512, 7, 7]               0
#       BatchNorm2d-23            [-1, 512, 7, 7]           1,024
#         MaxPool2d-24            [-1, 512, 3, 3]               0
#           Flatten-25                 [-1, 4608]               0
#            Linear-26                    [-1, 2]           9,218
# ================================================================
# Total params: 9,750,914
# Trainable params: 9,750,914
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 291.77
# Params size (MB): 37.20
# Estimated Total Size (MB): 329.54
# ----------------------------------------------------------------

# %% [markdown]
# ## 5.3 Try a forward pass on a single image (to test the model)
#
# Ok, we created a CNN-based model. But does this model work? To understand this, let's pass a image through the model.

# %%
model = model.to(device)  # device = "mps" or "cpu"
device
# Out:
# 'mps'

# %%
# 1. Get a batch of images and labels from the DataLoader
img_batch, label_batch = next(iter(train_dataloader_augmented))

# 2. Get a single image from the batch and unsqueeze the image so its shape fits the model
img_single, label_single = img_batch[0].unsqueeze(dim=0), label_batch[0]
print(f"Single image shape: {img_single.shape}\n")

# 3. Perform a forward pass on a single image
model.eval()
with torch.inference_mode():
    pred = model(img_single.to(device))

# 4. Print out what's happening and convert model logits -> pred probs -> pred label
print(f"Output logits:\n{pred}\n")
print(f"Output prediction probabilities:\n{torch.softmax(pred, dim=1)}\n")
print(f"Output prediction label:\n{torch.argmax(torch.softmax(pred, dim=1), dim=1)}\n")
print(f"Actual label:\n{label_single}")
# Out:
# Single image shape: torch.Size([1, 3, 224, 224])
#
# Output logits:
# tensor([[-0.0216,  0.0390]], device='mps:0')
#
# Output prediction probabilities:
# tensor([[0.4849, 0.5151]], device='mps:0')
#
# Output prediction label:
# tensor([1], device='mps:0')
#
# Actual label:
# 1

# %% [markdown]
# Nice! Our model is working for an image. Let's go ahead and try to understand this model.

# %% [markdown]
# ## 5.4 Understanding the model (check & confirm)
#
# It is important to understand the model architecture. Fortunately, there is the `torchinfo` package to see the architecture of the model. Let me show you.

# %%
# Install torchinfo if it's not available, import it if it is
try:
    import torchinfo
except:
    # !pip install torchinfo
    import torchinfo

from torchinfo import summary
# do a test pass through of an example input size
summary(model, input_size=[1, 3, IMAGE_WIDTH ,IMAGE_HEIGHT])
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ImageClassifier                          [1, 2]                    --
# ├─Sequential: 1-1                        [1, 64, 112, 112]         --
# │    └─Conv2d: 2-1                       [1, 64, 224, 224]         1,792
# │    └─ReLU: 2-2                         [1, 64, 224, 224]         --
# │    └─BatchNorm2d: 2-3                  [1, 64, 224, 224]         128
# │    └─MaxPool2d: 2-4                    [1, 64, 112, 112]         --
# ├─Sequential: 1-2                        [1, 512, 56, 56]          --
# │    └─Conv2d: 2-5                       [1, 512, 112, 112]        295,424
# │    └─ReLU: 2-6                         [1, 512, 112, 112]        --
# │    └─BatchNorm2d: 2-7                  [1, 512, 112, 112]        1,024
# │    └─MaxPool2d: 2-8                    [1, 512, 56, 56]          --
# ├─Sequential: 1-3                        [1, 512, 28, 28]          --
# │    └─Conv2d: 2-9                       [1, 512, 56, 56]          2,359,808
# │    └─ReLU: 2-10                        [1, 512, 56, 56]          --
# │    └─BatchNorm2d: 2-11                 [1, 512, 56, 56]          1,024
# │    └─MaxPool2d: 2-12                   [1, 512, 28, 28]          --
# ├─Sequential: 1-4                        [1, 512, 14, 14]          (recursive)
# │    └─Conv2d: 2-13                      [1, 512, 28, 28]          (recursive)
# │    └─ReLU: 2-14                        [1, 512, 28, 28]          --
# │    └─BatchNorm2d: 2-15                 [1, 512, 28, 28]          (recursive)
# │    └─MaxPool2d: 2-16                   [1, 512, 14, 14]          --
# ├─Sequential: 1-5                        [1, 512, 7, 7]            (recursive)
# │    └─Conv2d: 2-17                      [1, 512, 14, 14]          (recursive)
# │    └─ReLU: 2-18                        [1, 512, 14, 14]          --
# │    └─BatchNorm2d: 2-19                 [1, 512, 14, 14]          (recursive)
# │    └─MaxPool2d: 2-20                   [1, 512, 7, 7]            --
# ├─Sequential: 1-6                        [1, 512, 3, 3]            (recursive)
# │    └─Conv2d: 2-21                      [1, 512, 7, 7]            (recursive)
# │    └─ReLU: 2-22                        [1, 512, 7, 7]            --
# │    └─BatchNorm2d: 2-23                 [1, 512, 7, 7]            (recursive)
# │    └─MaxPool2d: 2-24                   [1, 512, 3, 3]            --
# ├─Sequential: 1-7                        [1, 2]                    --
# │    └─Flatten: 2-25                     [1, 4608]                 --
# │    └─Linear: 2-26                      [1, 2]                    9,218
# ==========================================================================================
# Total params: 2,668,418
# Trainable params: 2,668,418
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 13.62
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 188.26
# Params size (MB): 10.67
# Estimated Total Size (MB): 199.54
# ==========================================================================================

# %% [markdown]
# ## 5.5 Create train & test loop functions

# %% [markdown]
# Note that the model is built on the training data and tested on the validation set. Now let's create two function to train and test the model.

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    # Put model in train mode
    model.train()

    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0

    # Loop through data loader data batches
    for batch, (X, y) in enumerate(dataloader):
        # Send data to target device
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate  and accumulate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Calculate and accumulate accuracy metric across all batches
        y_pred_class = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
        train_acc += (y_pred_class == y).sum().item()/len(y_pred)

    # Adjust metrics to get average loss and accuracy per batch
    train_loss = train_loss / len(dataloader)
    train_acc = train_acc / len(dataloader)
    return train_loss, train_acc

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):

    # Put model in eval mode
    model.eval()

    # Setup test loss and test accuracy values
    test_loss, test_acc = 0, 0

    # Turn on inference context manager
    with torch.inference_mode():
        # Loop through DataLoader batches
        for batch, (X, y) in enumerate(dataloader):
            # Send data to target device
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred_logits = model(X)

            # 2. Calculate and accumulate loss
            loss = loss_fn(test_pred_logits, y)
            test_loss += loss.item()

            # Calculate and accumulate accuracy
            test_pred_labels = test_pred_logits.argmax(dim=1)
            test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))

    # Adjust metrics to get average loss and accuracy per batch
    test_loss = test_loss / len(dataloader)
    test_acc = test_acc / len(dataloader)
    return test_loss, test_acc

# %% [markdown]
# Now let's create a function named train to combine the train_step and test_step functions.

# %%
from tqdm.auto import tqdm

# 1. Take in various parameters required for training and test steps
def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):

    # 2. Create empty results dictionary
    results = {"train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

    # 3. Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
        train_loss, train_acc = train_step(model=model,
                                           dataloader=train_dataloader,
                                           loss_fn=loss_fn,
                                           optimizer=optimizer)
        test_loss, test_acc = test_step(model=model,
            dataloader=test_dataloader,
            loss_fn=loss_fn)

        # 4. Print out what's happening
        print(
            f"Epoch: {epoch+1} | "
            f"train_loss: {train_loss:.4f} | "
            f"train_acc: {train_acc:.4f} | "
            f"test_loss: {test_loss:.4f} | "
            f"test_acc: {test_acc:.4f}"
        )

        # 5. Update results dictionary
        results["train_loss"].append(train_loss)
        results["train_acc"].append(train_acc)
        results["test_loss"].append(test_loss)
        results["test_acc"].append(test_acc)

    # 6. Return the filled results at the end of the epochs
    return results

# %% [markdown]
# ## 5.6 Train and Evaluate Model

# %% [markdown]
# So far, we created training and test steps. We are ready to train the model using these steps. Show time:

# %%
device
# Out:
# 'mps'

# %%
# Set random seeds
torch.manual_seed(42)
#torch.cuda.manual_seed(42)
torch.manual_seed(42)

model.to(device)

# Set number of epochs
NUM_EPOCHS = 5

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=1e-3)

# Start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_results = train(model=model,
                      train_dataloader=train_dataloader_augmented,
                      test_dataloader=test_dataloader_augmented,
                      optimizer=optimizer,
                      loss_fn=loss_fn,
                      epochs=NUM_EPOCHS)

# End the timer and print out how long it took
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.9904 | train_acc: 0.5675 | test_loss: 0.7600 | test_acc: 0.5711
# Epoch: 2 | train_loss: 1.0512 | train_acc: 0.5825 | test_loss: 0.7523 | test_acc: 0.6137
# Epoch: 3 | train_loss: 0.9439 | train_acc: 0.5956 | test_loss: 0.6275 | test_acc: 0.6643
# Epoch: 4 | train_loss: 0.7114 | train_acc: 0.6470 | test_loss: 0.5418 | test_acc: 0.7260
# Epoch: 5 | train_loss: 0.5847 | train_acc: 0.6933 | test_loss: 0.5725 | test_acc: 0.6987
# Total training time: 1363.998 seconds

# %%
next(model.parameters()).device
# Out:
# device(type='mps', index=0)

# %%
print(images.device)
print(next(model.parameters()).device)
# Out:
# mps:0
# mps:0

# %% [markdown]
# ## 5.7 Plot the loss curves of Model
#
# To understand the performance of model, let's visualize the loss and accuracy values.

# %%
def plot_loss_curves(results):

    results = dict(list(model_results.items()))

    # Get the loss values of the results dictionary (training and test)
    loss = results['train_loss']
    test_loss = results['test_loss']

    # Get the accuracy values of the results dictionary (training and test)
    accuracy = results['train_acc']
    test_accuracy = results['test_acc']

    # Figure out how many epochs there were
    epochs = range(len(results['train_loss']))

    # Setup a plot
    plt.figure(figsize=(15, 7))

    # Plot loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss, label='train_loss')
    plt.plot(epochs, test_loss, label='test_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy, label='train_accuracy')
    plt.plot(epochs, test_accuracy, label='test_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %% [markdown]
# It is time to visualize for the loss and accuracy values using this function.

# %%
plot_loss_curves(model_results)

# %% [markdown]
# Awesome. The performance of our model is not bad on both the training and test datasets. Let's go ahead and take a look at how to make a prediction.

# %% [markdown]
# <a id="Prediction"></a>
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 20px;"><b>6. Make a Prediction</b></p>
#
# Now we had a good model for image classification. But, how does this model predict new data? To understand this let me make a prediction on a custom image.

# %%
# Choose a image.
custom_image_path = "./dog_test1.jpeg"

import torchvision
# Load in custom image and convert the tensor values to float32
custom_image = torchvision.io.read_image(str(custom_image_path)).type(torch.float32)

# Divide the image pixel values by 255 to get them between [0, 1]
custom_image = custom_image / 255.

# Print out image data
print(f"Custom image tensor:\n{custom_image}\n")
print(f"Custom image shape: {custom_image.shape}\n")
print(f"Custom image dtype: {custom_image.dtype}")
# Out:
# Custom image tensor:
# tensor([[[0.6510, 0.6510, 0.6549,  ..., 0.6588, 0.6627, 0.6667],
#          [0.6510, 0.6510, 0.6549,  ..., 0.6588, 0.6627, 0.6667],
#          [0.6510, 0.6510, 0.6549,  ..., 0.6588, 0.6627, 0.6667],
#          ...,
#          [0.6157, 0.6157, 0.6118,  ..., 0.6863, 0.6745, 0.6667],
#          [0.6118, 0.6118, 0.6118,  ..., 0.6824, 0.6706, 0.6627],
#          [0.6118, 0.6118, 0.6118,  ..., 0.6784, 0.6667, 0.6549]],
#
#         [[0.5451, 0.5451, 0.5490,  ..., 0.5451, 0.5490, 0.5529],
#          [0.5451, 0.5451, 0.5490,  ..., 0.5451, 0.5490, 0.5529],
#          [0.5451, 0.5451, 0.5490,  ..., 0.5451, 0.5490, 0.5529],
#          ...,
#          [0.5098, 0.5098, 0.5059,  ..., 0.5137, 0.4980, 0.4784],
#          [0.5059, 0.5059, 0.5059,  ..., 0.5098, 0.4941, 0.4745],
#          [0.5059, 0.5059, 0.5059,  ..., 0.5059, 0.4902, 0.4667]],
#
#         [[0.4706, 0.4706, 0.4745,  ..., 0.4745, 0.4784, 0.4824],
#          [0.4706, 0.4706, 0.4745,  ..., 0.4745, 0.4784, 0.4824],
#          [0.4706, 0.4706, 0.4745,  ..., 0.4745, 0.4784, 0.4824],
#          ...,
#          [0.4353, 0.4353, 0.4314,  ..., 0.3608, 0.3451, 0.3216],
#          [0.4314, 0.4314, 0.4314,  ..., 0.3569, 0.3412, 0.3176],
#          [0.4314, 0.4314, 0.4314,  ..., 0.3529, 0.3373, 0.3098]]])
#
# Custom image shape: torch.Size([3, 192, 204])
#
# Custom image dtype: torch.float32

# %% [markdown]
# Now let's create transform pipleine to resize image.

# %%
custom_image_transform = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
])

# Transform target image
custom_image_transformed = custom_image_transform(custom_image)

# Print out original shape and new shape
print(f"Original shape: {custom_image.shape}")
print(f"New shape: {custom_image_transformed.shape}")
# Out:
# Original shape: torch.Size([3, 192, 204])
# New shape: torch.Size([3, 224, 224])

# %% [markdown]
# First, let's fit the image for the model with the function we created and then make a prediction.

# %%
model.eval()
with torch.inference_mode():
    # Add an extra dimension to image
    custom_image_transformed_with_batch_size = custom_image_transformed.unsqueeze(dim=0)

    # Print out different shapes
    print(f"Custom image transformed shape: {custom_image_transformed.shape}")
    print(f"Unsqueezed custom image shape: {custom_image_transformed_with_batch_size.shape}")

    # Make a prediction on image with an extra dimension
    custom_image_pred = model(custom_image_transformed.unsqueeze(dim=0).to(device))
# Out:
# Custom image transformed shape: torch.Size([3, 224, 224])
# Unsqueezed custom image shape: torch.Size([1, 3, 224, 224])

# %% [markdown]
# Now let's take a look at our model's predictions.

# %%
custom_image_pred
# Out:
# tensor([[-0.2087,  0.2254]], device='mps:0')

# %% [markdown]
# Nice! we've seen the prediction values of the model. Let's take a look at the prediction class. First, let me show you the prediction values.

# %%
# Let's convert them from logits -> prediction probabilities -> prediction labels
# Print out prediction logits
print(f"Prediction logits: {custom_image_pred}")

# Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
custom_image_pred_probs = torch.softmax(custom_image_pred, dim=1)
print(f"Prediction probabilities: {custom_image_pred_probs}")

# Convert prediction probabilities -> prediction labels
custom_image_pred_label = torch.argmax(custom_image_pred_probs, dim=1)
print(f"Prediction label: {custom_image_pred_label}")
# Out:
# Prediction logits: tensor([[-0.2087,  0.2254]], device='mps:0')
# Prediction probabilities: tensor([[0.3931, 0.6069]], device='mps:0')
# Prediction label: tensor([1], device='mps:0')

# %% [markdown]
# It is time to find the predicted label.

# %%
custom_image_pred_class = class_names[custom_image_pred_label.cpu()] # put pred label to CPU, otherwise will error
custom_image_pred_class
# Out:
# 'dogs'

# %% [markdown]
# Let's visualize this image with matplotlib.

# %%
# Plot custom image
plt.imshow(custom_image.permute(1, 2, 0)) # need to permute image dimensions from CHW -> HWC otherwise matplotlib will error
plt.title(f"Image shape: {custom_image.shape}")
plt.axis(False);

# %% [markdown]
# # Conclusion
#
# In this notebook, you learned how to build an image classification model from scratch with Pytorch. Tensorflow is generally preferred for deep learning projects. However, with Pytorch you can better control the deep-learning analysis steps. Pytorch has been preferred more recently, especially in the academic community. we also talked about data augmentation and highlighted the importance of this technique.

# %% [markdown]
# # Resources
#
# - [Learn Pytorch](https://www.learnpytorch.io/)
# - [Modern Computer Vision with PyTorch](https://www.amazon.com/Modern-Computer-Vision-PyTorch-applications/dp/1839213477)
